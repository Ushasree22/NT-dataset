# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sb
import math,random as rd
# %matplotlib inline

# %%
A=pd.read_csv("/home/aipl-12/Downloads/NT_data_prakruti.csv")

# %%
A.head()
# Out:
#    Unnamed: 0  medical_id user_id  filename prakruti  patient_id  \
# 0           0           4     8_4   8_4.csv     vata           8
# 1           1           5     8_5   8_5.csv     vata           8
# 2           2           6     8_6   8_6.csv     vata           8
# 3           3          10    7_10  7_10.csv     Vata           7
# 4           4          11    7_11  7_11.csv     Vata           7
#
#            create_date gender          dateofbirth height  ...  km  vh  ph  \
# 0  2016-10-21 11:27:50      M  1994-10-21 00:00:00      1  ...  90   0  40
# 1  2016-10-21 11:43:45      M  1994-10-21 00:00:00    164  ...   0   0  20
# 2  2016-10-21 11:49:29      M  1994-10-21 00:00:00    164  ...  80  10  10
# 3  2016-10-21 13:24:42      M  1988-10-21 00:00:00    175  ...  90  10   0
# 4  2016-10-21 13:28:10      M  1988-10-21 00:00:00    175  ...   0   0  10
#
#    kh          Gati  Laghu-Guru  Kathina-Mrudu  Sthula-Sukshma  Tikshna-Manda  \
# ...

# %%
#multiple histograms

plt.hist(A['Agni'],
        color='blue',
        edgecolor='red',
        bins=10)

plt.show()

# %%
#colors=['orange','yellow','cyan','brown']
#plt.pie(A['percentage'],
      # labels=A['Agni'],
       #colors='colors',
       #autopct= '%.2f')
#plt.axis('equal')
#plt.show()

# %%
A.iloc[3:15,3:15]
# Out:
#      filename     prakruti  patient_id          create_date gender  \
# 3    7_10.csv         Vata           7  2016-10-21 13:24:42      M
# 4    7_11.csv         Vata           7  2016-10-21 13:28:10      M
# 5   20_38.csv         vata          20  2016-10-25 05:53:04      F
# 6   47_43.csv         vata          47  2016-10-27 11:00:50      M
# 7   47_44.csv         vata          47  2016-10-27 11:14:30      M
# 8   47_45.csv         vata          47  2016-10-27 11:38:20      M
# 9   47_47.csv         vata          47  2016-10-27 11:43:37      M
# 10  50_48.csv        Vata           50  2016-10-27 11:59:19      M
# 11  54_50.csv        Vata           54  2016-10-27 12:55:16      M
# 12  57_51.csv   Vata Pitta          57  2016-10-28 05:51:54      M
# 13  68_63.csv         Vata          68  2016-11-08 21:02:42      M
# 14  72_75.csv  Pitta Kapha          72  2016-11-08 22:50:19      F
#
#             dateofbirth height weight  Pulse-Rate     Rhythm Sama-Nirama  \
# ...

# %%
print(A[['Agni','gender','weight']])
# Out:
#        Agni gender weight
# 0        20      M      5
# 1        90      M     59
# 2        50      M     59
# 3        40      M     62
# 4        90      M     62
# 5        70      F     65
# 6        70      M     45
# 7        90      M     45
# 8        70      M     45
# 9        90      M     45
# 10       90      M     75
# 11       70      M     62
# 12       70      M     50
# 13       50      M     66
# 14       20      F     60
# 15       70      M     80
# 16       90      F     80
# 17       40      F     50
# 18       70      F     50
# 19       70      F     50
# 20       70      M     70
# 21       70      F     70
# 22       70      M     65
# 23       50      M     60
# 24       20      F     50
# 25       40      M     60
# 26       90      M     65
# 27       70      M     66
# 28       50      M     75
# 29       50      F     50
# ...     ...    ...    ...
# 45001    30      F     72
# 45002    70      M     65
# 45003    20      F     54
# ...

# %%
#plt.A[x='Agni',y='weight']
#A.plot(x='Agni',y='weight')
#plt.show()

# %%
sample_data={'Agni':np.random.rand(100),
             'weight': np.random.rand(100)}
A= pd.DataFrame(sample_data)
sb.scatterplot(x="Agni", y="weight", data=A)

# %%
#above and this are same but diffrnt formats
A.plot(kind="scatter",x="Agni",y="weight",color="red")
plt.show()

# %%
prakruti =["Vata Pitta","Pitta Kapha","Vata"]
height=160,170,180
fig=plt.figure(figsize=(8,6))
plt.bar(prakruti,height,width=0.3,color=("orange","yellow","red"))
plt.title("prakruti wrto Height",fontsize=10)
plt.xticks(prakruti)
plt.legend()
plt.show()

# %%
A.plot(kind='bar',x='weight',y='Agni')
#plt.xticks(weight,Agni)
plt.show()

# %%
ax=plt.gca()
A.plot(kind='line',x='Agni',y='weight',ax=ax)

plt.show()
